# %% [markdown]
# <a href="https://colab.research.google.com/github/ferdouszislam/Bangla-Handwritting-Aesthetics-Prediction-ML/blob/main/codes/experimentation_2_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import time
import copy
import torch
import numpy as np
import math
import torch.nn as nn
import matplotlib.pyplot as plt
import pandas as pd
import torchvision
import torchvision.transforms as transforms
from torchvision.utils import make_grid
from torch.utils.data import Dataset, DataLoader
from skimage import io
import matplotlib.pyplot as plt

# %%
# device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
# mount gdrive with this code
from google.colab import drive
drive.mount('/content/drive')

# extract the zip file containing our dataset
import zipfile
import os

zip_ref = zipfile.ZipFile('/content/drive/MyDrive/Colab Notebooks/BanglaLekha-Isolated_aesthetics_dataset/2_class.zip', 'r')
zip_ref.extractall('/tmp')
zip_ref.close()
# Out:
# Mounted at /content/drive

# %%
# set all random seeds
SEED = 42

def set_global_seed():
  #torch.backends.cudnn.deterministic = True
  #torch.backends.cudnn.benchmark = False
  #random.seed(SEED)
  torch.manual_seed(SEED)
  torch.cuda.manual_seed(SEED)
  torch.cuda.manual_seed_all(SEED)
  #np.random.seed(SEED)

set_global_seed()

# %%
# custom dataset class
class BanglaAestheticsDataset(Dataset):
  def __init__(self, labels_csv_file, img_dir, transform=None):
    self.labels_df = pd.read_csv(labels_csv_file)
    self.img_dir = img_dir
    self.transform = transform

  def __len__(self):
    return len(self.labels_df)

  def __getitem__(self, index):
    img_path = os.path.join(self.img_dir, self.labels_df.iloc[index, 0])
    image = io.imread(img_path)
    if self.transform:
      image = self.transform(image)
    y_label = torch.tensor(int(self.labels_df.iloc[index, 3]))
    
    return (image, y_label)

# %%
# load data

# resize to same shape and convert to tensor
custom_transform = transforms.Compose([transforms.ToPILImage(), 
                                       transforms.Resize((50, 50)), 
                                       transforms.ToTensor(),
                                       #transforms.Normalize((0.5,), (0.5,))
                                       ])

train_dataset = BanglaAestheticsDataset(labels_csv_file='/tmp/2_class/aesthetics_train.csv', 
                                        img_dir='/tmp/2_class/train_images', transform=custom_transform)
val_dataset = BanglaAestheticsDataset(labels_csv_file='/tmp/2_class/aesthetics_val.csv', 
                                        img_dir='/tmp/2_class/validation_images', transform=custom_transform)
test_dataset = BanglaAestheticsDataset(labels_csv_file='/tmp/2_class/aesthetics_test.csv', 
                                        img_dir='/tmp/2_class/test_images', transform=custom_transform)

# data loaders

batch_size = 100 # no of samples in a single batch

set_global_seed()
train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
set_global_seed()
val_loader = DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

# %%
# visualize data
def show_batch(dl):
    """Plot images grid of single batch"""
    for images, labels in dl:
        fig,ax = plt.subplots(figsize = (25,4))
        ax.set_xticks([])
        ax.set_yticks([])
        ax.imshow(make_grid(images,nrow=25).permute(1,2,0))
        #print(images.shape)
        break

# %%
show_batch(val_loader)

# %% [markdown]
# # Experimentation with various NNs starts from here

# %%
# hyperparameters
INPUT_SIZE = 50*50
ANN_FC1_SIZE = 256
ANN_FC2_SIZE = 128
ANN_FC3_SIZE = 64
CONV1_FILTERS = 16
CONV2_FILTERS = 32
NUM_EPOCHS = 80
LEARNING_RATE = 0.0015

# %%
# custom ANN class with 3 hidden layers, relu activation and dropout on each hidden layer
class ANN(nn.Module):
  def __init__(self, input_size=INPUT_SIZE, fc1_size=256, fc2_size=128, fc3_size=64):
    super(ANN, self).__init__()
    self.input_size = input_size
    self.fc1 = nn.Linear(input_size, fc1_size)
    self.dropout_fc1 = nn.Dropout(0.75)
    self.relu = nn.ReLU()
    self.fc2 = nn.Linear(fc1_size, fc2_size)
    self.dropout_fc2 = nn.Dropout(0.5)
    self.fc3 = nn.Linear(fc2_size, fc3_size)
    self.dropout_fc3 = nn.Dropout(0.5)
    self.output_layer = nn.Linear(fc3_size, 1)

  def forward(self, input):
    # flatten input
    input = input.reshape(-1, self.input_size) 
    # input layer to hidden layer 1
    output = self.dropout_fc1(self.fc1(input))
    output = self.relu(output)
    # hidden layer 1 to hidden layer 2
    output = self.dropout_fc2(self.fc2(output))
    output = self.relu(output)
    # hidden layer 2 to hidden layer 3
    output = self.dropout_fc3(self.fc3(output))
    output = self.relu(output)
    # hidden layer 3 to output
    output = self.output_layer(output)
    pred = torch.sigmoid(output) # probability prediction
    return pred

# %%
# custom cnn class 
class CNN(nn.Module):
  def __init__(self, conv1_filters=16, conv2_filters=32, fc1_size=256, fc2_size=64):
    super(CNN, self).__init__()
    
    self.conv1_filters = conv1_filters
    self.conv2_filters = conv2_filters

    self.conv_layer1 = nn.Sequential(
        nn.Conv2d(1, conv1_filters, kernel_size=3, stride=1, padding=1),
        nn.BatchNorm2d(conv1_filters),
        nn.Dropout(0.25),
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=2, stride=2)
    )

    self.conv_layer2 =  nn.Sequential(
        nn.Conv2d(conv1_filters, conv2_filters, kernel_size=3, stride=1, padding=1),
        nn.BatchNorm2d(conv2_filters),
        nn.Dropout(0.25),
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=2, stride=2)
    )

    # conv layer explanation with: conv1_filters=16, conv2_filters=32
    # 1x50x50 --conv1--> 16x50x50 --maxpool--> 16x25x25
    # 16x25x25 --conv2--> 32x25x25 --maxpool--> 32x12x12

    self.fc1 = nn.Linear(conv2_filters*12*12, fc1_size) 
    self.fc2 = nn.Linear(fc1_size, fc2_size)
    self.relu = nn.ReLU()
    self.fc_dropout = nn.Dropout(0.5)
    self.output_layer = nn.Linear(fc2_size, 1)
      
  def forward(self, input):
    #print('inside forward', input.shape)

    # input to conv_layer1
    output = self.conv_layer1(input)
    #print('after conv1', output.shape)

    # conv_layer1 to conv_layer2
    output = self.conv_layer2(output)
    #print('after conv2', output.shape)

    # conv_layer2 to fc1
    output = output.reshape(-1, self.conv2_filters*12*12) # flatten
    output = self.fc1(output)
    output = self.relu(self.fc_dropout(output))

    # fc1 to fc2
    output = self.fc2(output)
    output = self.relu(self.fc_dropout(output))

    # fc2 to prediction
    output = self.output_layer(output)
    pred = torch.sigmoid(output)

    return pred

  def _get_result_dims(input_dims, conv_dims, p=0, s=1):
    # get resulting matrix(2d) dimensions after convolution
    
    resulting_dims = []
    resulting_dims.append(int((input_dims[0] - conv_dims[0] + 2*p)/s)+1)
    resulting_dims.append(int((input_dims[1] - conv_dims[1] + 2*p)/s)+1)
    
    return resulting_dims

# %%
# class to calculate accuracy of model, using batches of data
class Accuracy_Calc():
  def __init__(self):
    self.n_correct_samples = 0
    self.n_total_samples = 0

  def add_batch(self, pred_labels, gt_labels):
    pred_labels = torch.round(pred_labels)
    gt_labels = torch.round(gt_labels)

    self.n_total_samples+=gt_labels.size(0)
    self.n_correct_samples+=pred_labels.eq(gt_labels).sum().item()

  def get_accuracy(self):
    return 100*self.n_correct_samples/self.n_total_samples

# %%
PATH_TO_ANN_MODEL = 'ann_model.pth'
PATH_TO_CNN_MODEL = 'cnn_model.pth'
PATH_TO_RESNET_TRANS = 'resnet_trans.pth'
PATH_TO_ALEXNET_TRANS = 'alexnet_trans.pth'
PATH_TO_SQUEEZENET_TRANS = 'squeezenet_trans.pth'

# training loop
def train(model, optimizer, criterion, train_loader, val_loader, num_epochs, SAVE_PATH):
  since = time.time()

  min_val_loss = np.inf
  total_train_step = len(train_loader)

  train_accuracies = []
  val_accuracies = []
  train_losses = []
  val_losses = []
  selected_epoch = 0
  selected_train_acc = 0.0
  selected_val_acc = 0.0
  selected_train_loss = 0.0
  selected_val_loss = 0.0
  
  # train loop
  for epoch in range(num_epochs):
    train_loss = 0.0
    train_acc_calc = Accuracy_Calc()
    
    model.train() # set the model in train mode
    for step, (images, labels) in enumerate(train_loader):
      images = images.to(device)
      labels = labels.to(device)

      outputs = model(images)
      labels = labels.unsqueeze(1)
      labels = labels.float()

      loss = criterion(outputs, labels)
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()

      # accumulate training loss
      train_loss+=loss.item()
      with torch.no_grad():
        # accumulate train accuracy
        train_acc_calc.add_batch(outputs, labels)

    val_loss = 0.0
    val_acc_calc = Accuracy_Calc()

    model.eval() # set the model to evaluation mode
    with torch.no_grad():
      for step, (images, labels) in enumerate(val_loader):
        # if flatten_input:
        #   images = images.reshape(-1, 50*50) # flatten image
        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)
        labels = labels.unsqueeze(1)
        labels = labels.float()

        loss = criterion(outputs, labels)

        # accumulate validation loss
        val_loss+=loss.item() #loss.item() * images.size(0)
        # accumulate validation accuracy
        val_acc_calc.add_batch(outputs, labels)

    train_loss /= len(train_loader)
    val_loss /= len(val_loader)
    train_acc = train_acc_calc.get_accuracy()
    val_acc = val_acc_calc.get_accuracy()
    train_accuracies.append(train_acc)
    val_accuracies.append(val_acc)
    train_losses.append(train_loss)
    val_losses.append(val_loss)
    
    print(f'Epoch {epoch} / {num_epochs-1}')
    print('-' * 15)
    print(f'train loss: {train_loss:.3f}, accuracy: {train_acc:.3f}')
    print(f'validation loss: {val_loss:.3f}, accuracy: {val_acc:.3f}')

    if val_loss < min_val_loss or (val_loss == min_val_loss and val_acc > selected_val_acc):
        print(f'validation loss decreased \t Saving The Model')
        min_val_loss = val_loss
        selected_train_acc = train_acc
        selected_train_loss = train_loss
        selected_val_acc = val_acc
        selected_val_loss = val_loss
        # Saving State Dict
        model.to(device)
        torch.save(model.state_dict(), SAVE_PATH)
        selected_epoch = epoch

    print()

  time_elapsed = time.time() - since
  print('Training complete in {:.0f}m {:.0f}s'.format(
  time_elapsed // 60, time_elapsed % 60))
  print(f'Train Accuracy: {selected_train_acc}, Loss: {selected_train_loss}\nValidation Accuracy: {selected_val_acc}, Loss: {selected_val_loss}')

  return selected_epoch, train_accuracies, val_accuracies, train_losses, val_losses

# evaluation 
def eval(model, test_loader):
  model.eval()
  with torch.no_grad():
    n_correct_samples = 0
    n_total_samples = 0
    for imgs, labels in test_loader:
      imgs = imgs.to(device)
      labels = labels.to(device).reshape(-1, 1)

      outputs = model(imgs)

      #pred = outputs.round() # if outputs>=0.5 class = 1, else class = 0
      pred = torch.round(outputs)

      #print(pred.shape, labels.shape)
      
      n_total_samples+=labels.size(0)
      n_correct_samples+=pred.eq(labels).sum().item()

    print(f'Accuracy = {100*n_correct_samples/n_total_samples : 0.3f}')

# plot lists of train, validation scores- accuracy, loss etc
def plot_scores(score_type, train_scores, val_scores, num_epochs=NUM_EPOCHS, selected_epoch=None):
  plt.figure(figsize =(15,9))
  plt.title(f"train vs validation {score_type}", fontdict = {'fontsize' : 18})
  epochs = [epoch for epoch in range(num_epochs)]
  plt.plot(epochs, train_scores, 'ro-',  epochs, val_scores ,'bv-')

  if selected_epoch:
    plt.axvline(x=selected_epoch, color='k', linestyle='--')
    plt.legend([f'train {score_type}',f'validation {score_type}', 'selected epoch'], fontsize=16)
  
  plt.xlabel('epochs', fontsize=18)
  plt.ylabel(score_type, fontsize=18)
  plt.xticks(fontsize=18)
  plt.yticks(fontsize=18)
  plt.show()

# %% [markdown]
# # **Custom ANN**

# %%
# init model with ANN
set_global_seed()
model = ANN(input_size=INPUT_SIZE, fc1_size=ANN_FC1_SIZE, fc2_size=ANN_FC2_SIZE, fc3_size=ANN_FC3_SIZE)
model = model.to(device)

# init loss function, optimizer
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

selected_epoch, train_accs, val_accs, train_losses, val_losses = train(model, optimizer, criterion, train_loader, val_loader, NUM_EPOCHS, SAVE_PATH=PATH_TO_ANN_MODEL)
# Out:
# Epoch 0 / 1
# ---------------
# train loss: 0.678, accuracy: 57.515
# validation loss: 0.657, accuracy: 61.337
# validation loss decreased 	 Saving The Model
#
# Epoch 1 / 1
# ---------------
# train loss: 0.665, accuracy: 59.890
# validation loss: 0.662, accuracy: 57.190
#
# Training complete in 4m 38s
# Train Accuracy: 57.514967805098465, Loss: 0.6775576318084128
# Validation Accuracy: 61.3371104815864, Loss: 0.6574462787160333

# %%
plot_scores("accuracy", train_accs, val_accs, NUM_EPOCHS, selected_epoch)

# %%
plot_scores("loss", train_losses, val_losses, NUM_EPOCHS, selected_epoch)

# %%
model = ANN(input_size=INPUT_SIZE, fc1_size=ANN_FC1_SIZE, fc2_size=ANN_FC2_SIZE, fc3_size=ANN_FC3_SIZE)
model.load_state_dict(torch.load(PATH_TO_ANN_MODEL))
model = model.to(device)
eval(model=model, test_loader=test_loader)

# %% [markdown]
# # **Custom CNN**

# %%
# init model with CNN
set_global_seed()
model = CNN()
model = model.to(device)

# init loss function, optimizer
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

selected_epoch, train_accs, val_accs, train_losses, val_losses = train(model, optimizer, criterion, train_loader, val_loader, NUM_EPOCHS, SAVE_PATH=PATH_TO_CNN_MODEL)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Epoch 0 / 79
# ---------------
# train loss: 0.643, accuracy: 62.826
# validation loss: 0.643, accuracy: 58.478
# Train-Validation loss difference decreased 	 Saving The Model
#
# Epoch 1 / 79
# ---------------
# train loss: 0.612, accuracy: 66.904
# validation loss: 0.623, accuracy: 68.083
#
# Epoch 2 / 79
# ---------------
# train loss: 0.596, accuracy: 68.437
# validation loss: 0.597, accuracy: 70.274
#
# Epoch 3 / 79
# ---------------
# train loss: 0.588, accuracy: 69.202
# validation loss: 0.608, accuracy: 66.232
#
# Epoch 4 / 79
# ---------------
# train loss: 0.581, accuracy: 69.705
# validation loss: 0.601, accuracy: 67.373
#
# Epoch 5 / 79
# ---------------
# train loss: 0.576, accuracy: 70.085
# validation loss: 0.605, accuracy: 68.280
#
# Epoch 6 / 79
# ---------------
# train loss: 0.571, accuracy: 70.644
# validation loss: 0.608, accuracy: 70.882
#
# Epoch 7 / 79
# ---------------
# train loss: 0.566, accuracy: 70.768
# validation loss: 0.579, accuracy: 72.748
#
# Epoch 8 / 79
# ---------------
# train loss: 0.561, accuracy: 71.084
# validation loss: 0.575, accuracy: 72.774
#
# Epoch 9 / 79
# ---------------
# train loss: 0.558, accuracy: 71.347
# validation loss: 0.587, accuracy: 70.455
#
# Epoch 10 / 79
# ---------------
# train loss: 0.555, accuracy: 71.677
# validation loss: 0.593, accuracy: 69.828
#
# Epoch 11 / 79
# ---------------
# train loss: 0.552, accuracy: 71.801
# validation loss: 0.569, accuracy: 72.801
#
# Epoch 12 / 79
# ---------------
# train loss: 0.549, accuracy: 71.965
# validation loss: 0.607, accuracy: 65.394
#
# Epoch 13 / 79
# ---------------
# train loss: 0.548, accuracy: 72.153
# validation loss: 0.587, accuracy: 68.975
#
# Epoch 14 / 79
# ---------------
# train loss: 0.545, accuracy: 72.189
# validation loss: 0.575, accuracy: 71.396
#
# Epoch 15 / 79
# ---------------
# train loss: 0.544, accuracy: 72.263
# validation loss: 0.583, accuracy: 70.984
#
# Epoch 16 / 79
# ---------------
# train loss: 0.542, accuracy: 72.505
# validation loss: 0.578, accuracy: 70.096
#
# Epoch 17 / 79
# ---------------
# train loss: 0.540, accuracy: 72.373
# validation loss: 0.584, accuracy: 71.207
#
# Epoch 18 / 79
# ---------------
# train loss: 0.538, accuracy: 72.609
# validation loss: 0.575, accuracy: 72.196
#
# Epoch 19 / 79
# ---------------
# train loss: 0.535, accuracy: 72.622
# validation loss: 0.581, accuracy: 70.489
#
# Epoch 20 / 79
# ---------------
# train loss: 0.533, accuracy: 72.856
# validation loss: 0.574, accuracy: 71.800
#
# Epoch 21 / 79
# ---------------
# train loss: 0.532, accuracy: 72.830
# validation loss: 0.576, accuracy: 71.535
#
# Epoch 22 / 79
# ---------------
# train loss: 0.530, accuracy: 72.962
# validation loss: 0.580, accuracy: 72.873
#
# Epoch 23 / 79
# ---------------
# train loss: 0.528, accuracy: 73.176
# validation loss: 0.573, accuracy: 73.605
#
# Epoch 24 / 79
# ---------------
# train loss: 0.528, accuracy: 73.049
# validation loss: 0.581, accuracy: 68.823
#
# Epoch 25 / 79
# ---------------
# train loss: 0.524, accuracy: 73.411
# validation loss: 0.568, accuracy: 72.789
#
# Epoch 26 / 79
# ---------------
# train loss: 0.523, accuracy: 73.524
# validation loss: 0.570, accuracy: 72.585
#
# Epoch 27 / 79
# ---------------
# train loss: 0.523, accuracy: 73.481
# validation loss: 0.562, accuracy: 72.310
#
# Epoch 28 / 79
# ---------------
# train loss: 0.519, accuracy: 73.541
# validation loss: 0.571, accuracy: 73.122
#
# Epoch 29 / 79
# ---------------
# train loss: 0.517, accuracy: 73.882
# validation loss: 0.558, accuracy: 73.590
#
# Epoch 30 / 79
# ---------------
# train loss: 0.514, accuracy: 73.849
# validation loss: 0.563, accuracy: 72.178
#
# Epoch 31 / 79
# ---------------
# train loss: 0.513, accuracy: 73.895
# validation loss: 0.562, accuracy: 73.212
#
# Epoch 32 / 79
# ---------------
# train loss: 0.508, accuracy: 73.984
# validation loss: 0.562, accuracy: 73.231
#
# Epoch 33 / 79
# ---------------
# train loss: 0.507, accuracy: 74.184
# validation loss: 0.567, accuracy: 73.269
#
# Epoch 34 / 79
# ---------------
# train loss: 0.504, accuracy: 74.405
# validation loss: 0.559, accuracy: 73.556
#
# Epoch 35 / 79
# ---------------
# train loss: 0.501, accuracy: 74.376
# validation loss: 0.553, accuracy: 74.009
#
# Epoch 36 / 79
# ---------------
# train loss: 0.500, accuracy: 74.432
# validation loss: 0.556, accuracy: 73.900
#
# Epoch 37 / 79
# ---------------
# train loss: 0.499, accuracy: 74.608
# validation loss: 0.562, accuracy: 73.775
#
# Epoch 38 / 79
# ---------------
# train loss: 0.499, accuracy: 74.438
# validation loss: 0.564, accuracy: 73.719
#
# Epoch 39 / 79
# ---------------
# train loss: 0.495, accuracy: 74.882
# validation loss: 0.561, accuracy: 73.692
#
# Epoch 40 / 79
# ---------------
# train loss: 0.492, accuracy: 75.013
# validation loss: 0.557, accuracy: 73.628
#
# Epoch 41 / 79
# ---------------
# train loss: 0.492, accuracy: 74.988
# validation loss: 0.557, accuracy: 73.262
#
# Epoch 42 / 79
# ---------------
# train loss: 0.490, accuracy: 74.987
# validation loss: 0.551, accuracy: 73.500
#
# Epoch 43 / 79
# ---------------
# train loss: 0.488, accuracy: 75.034
# validation loss: 0.564, accuracy: 73.348
#
# Epoch 44 / 79
# ---------------
# train loss: 0.485, accuracy: 75.306
# validation loss: 0.544, accuracy: 73.881
#
# Epoch 45 / 79
# ---------------
# train loss: 0.483, accuracy: 75.321
# validation loss: 0.546, accuracy: 73.858
#
# Epoch 46 / 79
# ---------------
# train loss: 0.482, accuracy: 75.244
# validation loss: 0.546, accuracy: 73.953
#
# Epoch 47 / 79
# ---------------
# train loss: 0.481, accuracy: 75.475
# validation loss: 0.556, accuracy: 72.646
#
# Epoch 48 / 79
# ---------------
# train loss: 0.479, accuracy: 75.652
# validation loss: 0.550, accuracy: 73.326
#
# Epoch 49 / 79
# ---------------
# train loss: 0.479, accuracy: 75.471
# validation loss: 0.550, accuracy: 73.299
#
# Epoch 50 / 79
# ---------------
# train loss: 0.473, accuracy: 75.786
# validation loss: 0.547, accuracy: 73.636
#
# Epoch 51 / 79
# ---------------
# train loss: 0.475, accuracy: 75.811
# validation loss: 0.563, accuracy: 73.802
#
# Epoch 52 / 79
# ---------------
# train loss: 0.473, accuracy: 75.881
# validation loss: 0.554, accuracy: 73.662
#
# Epoch 53 / 79
# ---------------
# train loss: 0.470, accuracy: 76.001
# validation loss: 0.559, accuracy: 73.148
#
# Epoch 54 / 79
# ---------------
# train loss: 0.471, accuracy: 76.009
# validation loss: 0.554, accuracy: 73.526
#
# Epoch 55 / 79
# ---------------
# train loss: 0.469, accuracy: 76.154
# validation loss: 0.557, accuracy: 73.628
#
# Epoch 56 / 79
# ---------------
# train loss: 0.466, accuracy: 76.229
# validation loss: 0.558, accuracy: 73.458
#
# Epoch 57 / 79
# ---------------
# train loss: 0.467, accuracy: 76.175
# validation loss: 0.562, accuracy: 72.351
#
# Epoch 58 / 79
# ---------------
# train loss: 0.464, accuracy: 76.453
# validation loss: 0.559, accuracy: 73.628
#
# Epoch 59 / 79
# ---------------
# train loss: 0.462, accuracy: 76.468
# validation loss: 0.553, accuracy: 73.651
#
# Epoch 60 / 79
# ---------------
# train loss: 0.461, accuracy: 76.533
# validation loss: 0.554, accuracy: 73.224
#
# Epoch 61 / 79
# ---------------
# train loss: 0.461, accuracy: 76.760
# validation loss: 0.551, accuracy: 73.443
#
# Epoch 62 / 79
# ---------------
# train loss: 0.461, accuracy: 76.692
# validation loss: 0.551, accuracy: 73.518
#
# Epoch 63 / 79
# ---------------
# train loss: 0.459, accuracy: 76.725
# validation loss: 0.555, accuracy: 73.813
#
# Epoch 64 / 79
# ---------------
# train loss: 0.457, accuracy: 76.959
# validation loss: 0.551, accuracy: 73.545
#
# Epoch 65 / 79
# ---------------
# train loss: 0.456, accuracy: 76.999
# validation loss: 0.548, accuracy: 73.821
#
# Epoch 66 / 79
# ---------------
# train loss: 0.453, accuracy: 77.181
# validation loss: 0.556, accuracy: 73.352
#
# Epoch 67 / 79
# ---------------
# train loss: 0.454, accuracy: 77.273
# validation loss: 0.550, accuracy: 73.824
#
# Epoch 68 / 79
# ---------------
# train loss: 0.451, accuracy: 77.202
# validation loss: 0.553, accuracy: 72.257
#
# Epoch 69 / 79
# ---------------
# train loss: 0.450, accuracy: 77.250
# validation loss: 0.555, accuracy: 72.971
#
# Epoch 70 / 79
# ---------------
# train loss: 0.451, accuracy: 77.261
# validation loss: 0.552, accuracy: 72.895
#
# Epoch 71 / 79
# ---------------
# train loss: 0.449, accuracy: 77.410
# validation loss: 0.551, accuracy: 73.432
#
# Epoch 72 / 79
# ---------------
# train loss: 0.448, accuracy: 77.610
# validation loss: 0.549, accuracy: 73.484
#
# Epoch 73 / 79
# ---------------
# train loss: 0.447, accuracy: 77.502
# validation loss: 0.548, accuracy: 73.530
#
# Epoch 74 / 79
# ---------------
# train loss: 0.446, accuracy: 77.563
# validation loss: 0.549, accuracy: 73.632
#
# Epoch 75 / 79
# ---------------
# train loss: 0.443, accuracy: 77.897
# validation loss: 0.551, accuracy: 73.700
#
# Epoch 76 / 79
# ---------------
# train loss: 0.443, accuracy: 77.880
# validation loss: 0.550, accuracy: 73.360
#
# Epoch 77 / 79
# ---------------
# train loss: 0.441, accuracy: 77.721
# validation loss: 0.549, accuracy: 73.084
#
# Epoch 78 / 79
# ---------------
# train loss: 0.440, accuracy: 77.919
# validation loss: 0.543, accuracy: 73.760
#
# Epoch 79 / 79
# ---------------
# train loss: 0.438, accuracy: 78.092
# validation loss: 0.552, accuracy: 73.065
#
# Training complete in 223m 55s

# %%
plot_scores("accuracy", train_accs, val_accs, NUM_EPOCHS, selected_epoch)

# %%
plot_scores("loss", train_losses, val_losses, NUM_EPOCHS, selected_epoch)

# %%
model = CNN()
model.load_state_dict(torch.load(PATH_TO_CNN_MODEL))
model = model.to(device)
eval(model=model, test_loader=test_loader)
# Out:
# Accuracy =  57.407

# %% [markdown]
# # **Transfer Learning**

# %%
from torchvision import models

# %%
# resize to same shape and convert to tensor
tm_transform = transforms.Compose([transforms.ToPILImage(), 
                                   transforms.Resize((224, 224)),
                                   transforms.ToTensor(),
                                   transforms.Lambda(lambda img: img.repeat(3, 1, 1) ), # repeat single channel thrice to get 3-channel 
                                   transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
                                   ])

# load datasets
tm_train_dataset = BanglaAestheticsDataset(labels_csv_file='/tmp/2_class/aesthetics_train.csv', 
                                        img_dir='/tmp/2_class/train_images', transform=tm_transform)
tm_val_dataset = BanglaAestheticsDataset(labels_csv_file='/tmp/2_class/aesthetics_val.csv', 
                                        img_dir='/tmp/2_class/validation_images', transform=tm_transform)
tm_test_dataset = BanglaAestheticsDataset(labels_csv_file='/tmp/2_class/aesthetics_test.csv', 
                                        img_dir='/tmp/2_class/test_images', transform=tm_transform)

# data-loaders

batch_size = 100 # no of samples in a single batch

set_global_seed()
tm_train_loader = DataLoader(dataset=tm_train_dataset, batch_size=batch_size, shuffle=True)
set_global_seed()
tm_val_loader = DataLoader(dataset=tm_val_dataset, batch_size=batch_size, shuffle=True)
tm_test_loader = DataLoader(dataset=tm_test_dataset, batch_size=batch_size, shuffle=False)

# %%
show_batch(val_loader)

# %%
class TransferModel(nn.Module):
  def __init__(self, model_name='resnet-18'):
    super(TransferModel, self).__init__()
    
    if model_name == 'resnet-18':
      self.base_model = models.resnet18(pretrained=True)
    elif model_name == 'alexnet':
      self.base_model = models.alexnet(pretrained=True)
    elif model_name == 'squeezenet':
      self.base_model = models.squeezenet1_1(pretrained=True)
    
    # freeze resnet beginning layers
    for param in self.base_model.parameters():
      param.requires_grad = False

    # output to one neuron
    if model_name == 'resnet-18':
      self.base_model.fc = nn.Linear(self.base_model.fc.in_features, 1)
    elif model_name == 'alexnet':
      self.base_model.classifier[6] = nn.Linear(self.base_model.classifier[6].in_features, 1)
    elif model_name == 'squeezenet':
      self.base_model.classifier._modules["1"] = nn.Conv2d(512, 1, kernel_size=(1, 1))


  def forward(self, input):
    output = self.base_model(input)
    return torch.sigmoid(output)

# %% [markdown]
# ### ResNet

# %%
# class ResNetTM(nn.Module):
#   def __init__(self):
#     super(ResNetTM, self).__init__()

#     # # convert 1 channel to 3 channels
#     # self.conv = nn.Sequential(
#     #     nn.Conv2d(1, 3, kernel_size=3, stride=1, padding=1),
#     #     nn.BatchNorm2d(3),
#     #     nn.Dropout(0.25),
#     #     nn.ReLU()
#     # )
    
#     # ResNet-18
#     self.base_model = models.resnet18(pretrained=True)
#     # freeze resnet beginning layers
#     for param in self.base_model.parameters():
#       param.requires_grad = False

#     # output to one neuron
#     self.base_model.fc = nn.Linear(self.base_model.fc.in_features, 1)

#   def forward(self, input):
#     output = self.base_model(input)
#     return torch.sigmoid(output)

# %%
# init model with ResNet-18
set_global_seed()

model = TransferModel('resnet-18')
model = model.to(device)

# init loss function, optimizer
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

selected_epoch, train_accs, val_accs, train_losses, val_losses = train(model, optimizer, criterion, tm_train_loader, tm_val_loader, NUM_EPOCHS, SAVE_PATH=PATH_TO_RESNET_TRANS)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]
# Epoch 0 / 1
# ---------------
# train loss: 0.620, accuracy: 65.521
# validation loss: 0.590, accuracy: 68.370
# Train-Validation loss difference decreased 	 Saving The Model
#
# Epoch 1 / 1
# ---------------
# train loss: 0.607, accuracy: 67.090
# validation loss: 0.613, accuracy: 66.195
# Train-Validation loss difference decreased 	 Saving The Model
#
# Training complete in 17m 37s

# %%
plot_scores('accuracy', train_accs, val_accs, NUM_EPOCHS, selected_epoch)

# %%
plot_scores('loss', train_losses, val_losses, NUM_EPOCHS, selected_epoch)

# %%
model = TransferModel('resnet-18')
model.load_state_dict(torch.load(PATH_TO_RESNET_TRANS))
model = model.to(device)
eval(model=model, test_loader=tm_test_loader)
# Out:
# Accuracy =  63.840

# %% [markdown]
# ### AlexNet

# %%
# init model with AlexNet
set_global_seed()

model = TransferModel('alexnet')
model = model.to(device)

# init loss function, optimizer
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

selected_epoch, train_accs, val_accs, train_losses, val_losses = train(model, optimizer, criterion, tm_train_loader, tm_val_loader, NUM_EPOCHS, SAVE_PATH=PATH_TO_ALEXNET_TRANS)
# Out:
# Epoch 0 / 1
# ---------------
# train loss: 0.658, accuracy: 62.606
# validation loss: 0.598, accuracy: 67.694
# Train-Validation loss difference decreased 	 Saving The Model
#
# Epoch 1 / 1
# ---------------
# train loss: 0.655, accuracy: 63.363
# validation loss: 0.596, accuracy: 67.796
# Train-Validation loss difference decreased 	 Saving The Model
#
# Training complete in 13m 30s

# %%
plot_scores('accuracy', train_accs, val_accs, NUM_EPOCHS, selected_epoch)

# %%
plot_scores('loss', train_losses, val_losses, NUM_EPOCHS, selected_epoch)

# %%
model = TransferModel('alexnet')
model.load_state_dict(torch.load(PATH_TO_ALEXNET_TRANS))
model = model.to(device)
eval(model=model, test_loader=tm_test_loader)
# Out:
# Accuracy =  65.161

# %% [markdown]
# ### SqueezeNet

# %%
# init model with SqueezeNet1_1
set_global_seed()

model = TransferModel('squeezenet')
model = model.to(device)

# init loss function, optimizer
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

selected_epoch, train_accs, val_accs, train_losses, val_losses = train(model, optimizer, criterion, tm_train_loader, tm_val_loader, NUM_EPOCHS, SAVE_PATH=PATH_TO_SQUEEZENET_TRANS)
# Out:
# Downloading: "https://download.pytorch.org/models/squeezenet1_1-b8a52dc0.pth" to /root/.cache/torch/hub/checkpoints/squeezenet1_1-b8a52dc0.pth
#   0%|          | 0.00/4.73M [00:00<?, ?B/s]
# Epoch 0 / 1
# ---------------
# train loss: 0.684, accuracy: 51.585
# validation loss: 0.684, accuracy: 61.432
# Train-Validation loss difference decreased 	 Saving The Model
#
# Epoch 1 / 1
# ---------------
# train loss: 0.677, accuracy: 53.322
# validation loss: 0.681, accuracy: 62.119
#
# Training complete in 14m 33s

# %%
plot_scores('accuracy', train_accs, val_accs, NUM_EPOCHS, selected_epoch)

# %%
plot_scores('loss', train_losses, val_losses, NUM_EPOCHS, selected_epoch)

# %%
model = TransferModel('squeezenet')
model.load_state_dict(torch.load(PATH_TO_SQUEEZENET_TRANS))
model = model.to(device)
eval(model=model, test_loader=tm_test_loader)
# Out:
# Accuracy =  60.496
